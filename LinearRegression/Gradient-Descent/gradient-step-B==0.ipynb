# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=42)

# %%
X
# Out:
# array([[ 0.64768854],
#        [-0.1382643 ],
#        [ 1.52302986],
#        [ 0.49671415]])

# %%
y
# Out:
# array([-36.36510221,  78.68404196, -18.25147982,  30.07297006])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-57.99225681])

# %%
regressor.intercept_
# Out:
# np.float64(50.20315110942306)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X),color='red')

# %%
y_pred = ((-57.99*X)+0)

# %%
y_pred.reshape(4)
# Out:
# array([-37.55945832,   8.01794682, -88.32050137, -28.80445373])

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='green', label='OLS')
plt.plot(X, y_pred, color='red', label='b=0')
plt.legend()
plt.show()

# %%
m = -57.99
b = 0
loss_slope = -2 * np.sum(y- m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-401.6137931894333)

# %%
learning_rate = 0.01
step_size = loss_slope * learning_rate
step_size
# Out:
# np.float64(-4.016137931894333)

# %%
b = b - step_size
b
# Out:
# np.float64(4.016137931894333)

# %%
y_pred1 = ((-57.99*X)+4.01)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='black', label='OLS')
plt.plot(X, y_pred1, color='#00a65a', label='b={}'.format(b))
plt.plot(X, y_pred, color='pink', label='b=0')
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y- m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-369.4846897342786)

# %%
step_size = loss_slope * learning_rate
step_size
# Out:
# np.float64(-3.6948468973427864)

# %%
b = b - step_size
b
# Out:
# np.float64(7.71098482923712)

# %%
y_pred2 = ((-57.99*X)+7.71)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='black', label='OLS')
plt.plot(X, y_pred2, color='yellow', label='b={}'.format(b))
plt.plot(X, y_pred1, color='#00a65a', label='b={}'.format(b))
plt.plot(X, y_pred, color='pink', label='b=0')
plt.legend()
plt.show()
