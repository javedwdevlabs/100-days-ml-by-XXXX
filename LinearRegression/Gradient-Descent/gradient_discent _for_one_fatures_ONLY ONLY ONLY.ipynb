# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X, y  = make_regression(n_samples=4,n_features=1,n_informative=1,noise=80, n_targets=1)

# %%
X
# Out:
# array([[0.94277834],
#        [1.66453696],
#        [1.53321009],
#        [1.57816448]])

# %%
y
# Out:
# array([ -7.26671143,  -3.94548328,  58.08486254, -12.22231252])

# %%
plt.scatter(X,y)
plt.show()

# %%
regressor =  LinearRegression()

# %%
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# np.float64(-21.297089660866632)

# %%
b = -21.29

# %%
regressor.coef_
# Out:
# array([20.95562387])

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X),color='red')
plt.show()

# %%
m = 20.95

# %%
b = 0

# %%
y_pred = ((20.95 * X)+100)

# %%
plt.scatter(X,y)
plt.plot(X,regressor.predict(X), color='red', label='first line')
plt.plot(X, y_pred,color='green',label='dusri line')
plt.legend()
plt.show()

# %%
m = 20.95
b = 100

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(970.3123949488552)

# %%
b = b - 0.01 * loss_slope
b
# Out:
# np.float64(80.59375210102289)

# %%
y_pred2 = ((m * X) + b)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='red', label='OLS')
plt.plot(X, y_pred, color='orange', label='second line')
plt.plot(X, y_pred2, color='green', label='third line')
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(815.0624117570383)

# %%
b = b - 0.03 * loss_slope
b
# Out:
# np.float64(47.99125563074135)

# %%
y_pred3 = ((m * X) + b)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='red', label='OLS')
plt.plot(X, y_pred, color='orange', label='second line')
plt.plot(X, y_pred2, color='green', label='third line')
plt.plot(X, y_pred3, color='#B6DB00', label='forth line')

plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(554.242439994786)

# %%
b = b - 0.03 * loss_slope
b
# Out:
# np.float64(14.736709231054192)

# %%
y_pred4 = ((m * X) + b)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='red', label='OLS')
plt.plot(X, y_pred, color='orange', label='second line')
plt.plot(X, y_pred2, color='green', label='third line')
plt.plot(X, y_pred3, color='#B6DB00', label='forth line')
plt.plot(X, y_pred4, color='#4B75FF', label='forth line')


plt.show()

# %%
loss_slope = -2 * np.sum(y - 500*X.ravel() - b)
loss_slope
# Out:
# np.float64(5752.875551440688)

# %%
b = b - 0.03 * loss_slope
b
# Out:
# np.float64(-159.650467601061)

# %%
y_pred5 = ((m * X) + b)

# %%
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='red', label='OLS')
plt.plot(X, y_pred, color='orange', label='second line')
plt.plot(X, y_pred2, color='green', label='third line')
plt.plot(X, y_pred3, color='#B6DB00', label='forth line')
plt.plot(X, y_pred4, color='#4B75FF', label='forth line')
plt.plot(X, y_pred5, color='#B6DB00', label='fifth line')


plt.legend()
plt.show()
