# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
X_train.shape
# Out:
# (353, 10)

# %%
class SGDRegressor:
  def __init__(self, learning_rate= 0.01, epochs=50):
    self.learning_rate = learning_rate
    self.epochs = epochs

  def fit(self, X_train, y_train):
    self.intercept = 0
    self.coef = np.ones(X_train.shape[1])

    for i in range(self.epochs):
      for j in range(X_train.shape[0]):
        idx = np.random.randint(0,X_train.shape[0])
        yhat = np.dot(X_train[idx],self.coef) + self.intercept
        intercept_slope = -2 * (y_train[idx] - yhat)
        coef_slope  = -2 * np.dot((y_train[idx] - yhat),X_train[idx])
        self.intercept = self.intercept - (self.learning_rate * intercept_slope)
        self.coef = self.coef - (self.learning_rate * coef_slope)
    print(self.intercept, self.coef)
  def predict(self,X_test):
    return np.dot(X_test, self.coef) + self.intercept

# %%
import numpy as np

class SGDRegressor:
  def __init__(self, learning_rate=0.01, epochs=50):
    self.learning_rate = learning_rate
    self.epochs = epochs
    self.intercept_ = None
    self.coef_ = None

  def fit(self, X_train, y_train):
    # Standard naming convention ke liye 0.0 aur array float rakhein
    self.intercept_ = 0.0
    self.coef_ = np.ones(X_train.shape[1])
    n_samples = X_train.shape[0]

    for i in range(self.epochs):
      # Har epoch ke starting me data ko shuffle karne ke liye indices generator
      indices = np.arange(n_samples)
      np.random.shuffle(indices)

      for idx in indices:
        # Sahi randomized loop jo har data point ko check karega
        yhat = np.dot(X_train[idx], self.coef_) + self.intercept_

        # Slopes calculation (Bilkul sahi calculate kiya hai aapne)
        intercept_slope = -2 * (y_train[idx] - yhat)
        coef_slope = -2 * np.dot((y_train[idx] - yhat), X_train[idx])

        # Weights update
        self.intercept_ = self.intercept_ - (self.learning_rate * intercept_slope)
        self.coef_ = self.coef_ - (self.learning_rate * coef_slope)

    print("Training Complete. Intercept:", self.intercept_, "Coef:", self.coef_)

  def predict(self, X_test):
    return np.dot(X_test, self.coef_) + self.intercept_

# %%
gd_lr = SGDRegressor(0.01, 50)

# %%
start = time.time()
gd_lr.fit(X_train,y_train)
print("Time taken:", time.time() - start)
# Out:
# Training Complete. Intercept: 157.80430376407656 Coef: [  57.00241469  -68.4561019   353.29748131  249.04721002   17.51456033
#   -28.30751283 -173.60251631  130.51646081  319.97905361  130.13359521]
# Time taken: 0.4619777202606201

# %%
y_pred = gd_lr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43341551234310915

# %%
indices = np.arange(X_train.shape[0])
indices
val = np.random.shuffle(indices)
val
